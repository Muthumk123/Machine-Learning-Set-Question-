# %%
#1.
# Question 1:A retail store wants to identify customers who make frequent purchases. Given the dataset below, write a Python program to:
# Group customers by their IDs.


# Calculate the total purchase amount per customer.


# Identify the top 3 customers with the highest purchase amounts
#Dataset:
import pandas as pd
data = {'Customer_ID': [101, 102, 103, 101, 104, 102, 101, 105, 102, 103],
        'Purchase_Amount': [200, 150, 180, 220, 300, 200, 100, 400, 250, 300]}
df = pd.DataFrame(data)
total = df.groupby('Customer_ID', as_index=False).sum()
top3 = total.sort_values('Purchase_Amount', ascending=False).head(3)
print("Total Purchases per Customer:")
print(total)
print("Top 3 Frequent Customers:")
print(top3)
# Expected Output:
# Total Purchases per Customer:
#    Customer_ID  Purchase_Amount
# 0          101              520
# 1          102              600
# 2          103              480
# 3          104              300
# 4          105              400

# Top 3 Frequent Customers:
#    Customer_ID  Purchase_Amount
# 1          102              600
# 0          101              520
# 2          103              480
# Out:
# Total Purchases per Customer:
#    Customer_ID  Purchase_Amount
# 0          101              520
# 1          102              600
# 2          103              480
# 3          104              300
# 4          105              400
# Top 3 Frequent Customers:
#    Customer_ID  Purchase_Amount
# 1          102              600
# 0          101              520
# 2          103              480

# %%
#2. Predicting House Prices with Linear Regression
# A real estate company wants to predict house prices based on square footage. Write a Python program to:
# Train a Linear Regression model.
# Predict house prices for given test data.
# Dataset:
import pandas as pd
from sklearn.linear_model  import LinearRegression
data = {'Square_Feet': [1500, 2000, 2500, 3000, 3500],'Price': [300000, 400000, 500000, 600000, 700000]}
df= pd.DataFrame(data)
X=df[['Square_Feet']]
y=df['Price']
model=LinearRegression()
model.fit(X,y)
test_Data=[[1800],[2800]]
predict_price=model.predict(test_Data)
print("Predicted Prices:")
print(predict_price)

# Test Data: [[1800], [2800]]
# Expected Output:
# Predicted Prices:
# [360000. 560000.]
# Out:
# Predicted Prices:
# [360000. 560000.]
# C:\Users\Dell\anaconda3\envs\aiml\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# #3:
# Identifying Frequent Labels in a Dataset
# A company wants to identify the top 3 most common categories in a dataset. Given the dataset below, write a Python program to:
# Group the data by Category.


# Count the total occurrences of each category.


# Identify the top 3 most frequent categories.


# Dataset:
import pandas as pd
data = {'Category': ['A', 'B', 'C', 'A', 'D', 'B', 'A', 'E', 'B', 'C', 'C', 'A'],
        'Value': [10, 15, 20, 30, 25, 18, 22, 40, 35, 50, 45, 15]}
df=pd.DataFrame(data)
count = df.groupby('Category', as_index=False).count()
top3 = total.sort_values('Value', ascending=False).head(3)
print("Total Occurrences per Category:")
print(count)
print("Top 3 Frequent Categories:")
print(top3)


# Expected Output:

# Total Occurrences per Category:
#   Category  Count
# 0        A      4
# 1        B      3
# 2        C      3
# 3        D      1
# 4        E      1

# Top 3 Frequent Categories:
#   Category  Count
# 0        A      4
# 1        B      3
# 2        C      3
# Out:
# Total Occurrences per Category:
#   Category  Value
# 0        A      4
# 1        B      3
# 2        C      3
# 3        D      1
# 4        E      1
# Top 3 Frequent Categories:
#   Category  Value
# 0        A      4
# 1        B      3
# 2        C      3

# %%
#4.
# Predicting Missing Values Using Mean Imputation
# A dataset contains missing values in the Age column. Write a Python program to:
# Replace missing values with the mean of the column.


# Display the updated DataFrame.


# Dataset:
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
        'Age': [25, 30, None, 35, None]}
df = pd.DataFrame(data)
print("Original Data:")
print(df)
mean_age = df['Age'].mean()
df['Age'].fillna(mean_age, inplace=True)
print("Data after Imputation:")
print(df)

# Expected Output:

# Original Data:
#      Name   Age
# 0  Alice  25.0
# 1    Bob  30.0
# 2 Charlie   NaN
# 3  David  35.0
# 4    Eve   NaN

# Data after Imputation:
#      Name   Age
# 0  Alice  25.0
# 1    Bob  30.0
# 2 Charlie  30.0
# 3  David  35.0
# 4    Eve  30.0
# Out:
# Original Data:
#       Name   Age
# 0    Alice  25.0
# 1      Bob  30.0
# 2  Charlie   NaN
# 3    David  35.0
# 4      Eve   NaN
# Data after Imputation:
#       Name   Age
# 0    Alice  25.0
# 1      Bob  30.0
# 2  Charlie  30.0
# 3    David  35.0
# 4      Eve  30.0
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9020\3490027432.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(mean_age, inplace=True)

# %%
# 5: 
# Implementing a Simple Linear Regression Model
# You are given a dataset with Experience (years) and Salary ($). Write a Python program to:
# Train a Linear Regression model.


# Predict the salary for an individual with 6 years of experience.


# Dataset:
import pandas as pd
from sklearn.linear_model  import LinearRegression
data = {'Experience': [1, 2, 3, 4, 5], 
        'Salary': [30000, 35000, 40000, 45000, 50000]}
df = pd.DataFrame(data)
X=df[['Experience']]
y=df['Salary']
model_sl=LinearRegression()
model_sl.fit(X,y)
predicted_salary = model_sl.predict([[6]])
print("Predicted Salary for 6 years of experience:$",int(predicted_salary[[0]]))
    

















# Expected Output (Example):

# Predicted Salary for 6 years of experience: $55000
# Out:
# Predicted Salary for 6 years of experience:$ 55000
# C:\Users\Dell\anaconda3\envs\aiml\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9020\3954096650.py:21: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Predicted Salary for 6 years of experience:$",int(predicted_salary[[0]]))
