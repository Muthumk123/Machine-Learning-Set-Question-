# %%
A bank wants to predict whether a loan applicant will default based on credit score, income, and past loan history. What type of ML problem is this, 
wand what steps would you take to solve it?

ML
Superviesd
Classification
Step1. Create the dataset preprocess
Step2 . Import the pandas and upload the dataset
Step 3. Use get dummies for regression
Step 4. Split the input and output
Step 5. Import test train split and split
Step 6.Create model to predict  for geting  the best prediction model type Linear Regression ,Logical , Random Forest,Driction Tree, SVM  if need add StandardScaler
Step 7 .After Geting the best prediction save the model and deploy for production

# %%
2.	A retail store wants to predict the demand for different products to optimize inventory levels.
    What type of ML problem is this, and what steps would you take to solve it?
ML
Superviesd
Regression
Step1. Create the dataset preprocess
Step2 . Import the pandas and upload the dataset
Step 3. Use get dummies for regression
Step 4. Split the input and output
Step 5. Import test train split and split
Step 6.Create model to predict  for geting  the best prediction model type Linear Regression ,Logical , Random Forest,Driction Tree, SVM  if need add StandardScaler
Step 7 .After Geting the best prediction save the model and deploy for production

# %%
3.	A factory wants to detect whether a manufactured product is defective based on sensor readings and quality control data. 
    What type of ML problem is this, and what steps would you take to solve it?

ML
Superviesd
Classification
Step1. Create the dataset preprocess
Step2 . Import the pandas and upload the dataset
Step 3. Use get dummies for regression
Step 4. Split the input and output
Step 5. Import test train split and split
Step 6.Create model to predict  for geting  the best prediction model type Linear Regression ,Logical , Random Forest,Driction Tree, SVM  if need add StandardScaler
Step 7 .After Geting the best prediction save the model and deploy for production

# %%
4.	A healthcare provider wants to analyze patient symptoms and classify them into different disease categories.
    What type of ML problem is this, and what steps would you take to solve it?
ML
Superviesd
Classification
Step1. Create the dataset preprocess
Step2 . Import the pandas and upload the dataset
Step 3. Use get dummies for regression
Step 4. Split the input and output
Step 5. Import test train split and split
Step 6.Create model to predict  for geting  the best prediction model type Linear Regression ,Logical , Random Forest,Driction Tree, SVM  if need add StandardScaler
Step 7 .After Geting the best prediction save the model and deploy for production

# %%
5.	An e-commerce company wants to identify and remove fake reviews posted by bots or fraudsters.
    What type of ML problem is this, and what steps would you take to solve it?
ML
Superviesd
Classification
Step1. Create the dataset preprocess
Step2 . Import the pandas and upload the dataset
Step 3. Use get dummies for regression
Step 4. Split the input and output
Step 5. Import test train split and split
Step 6.Create model to predict  for geting  the best prediction model type Linear Regression ,Logical , Random Forest,Driction Tree, SVM  if need add StandardScaler
Step 7 .After Geting the best prediction save the model and deploy for production

# %%
6.	A financial firm wants to predict stock price movements based on historical price data and market indicators.
    What type of ML problem is this, and what steps would you take to solve it?
ML
Superviesd
Regression
Step1. Create the dataset preprocess
Step2 . Import the pandas and upload the dataset
Step 3. Use get dummies for regression
Step 4. Split the input and output
Step 5. Import test train split and split
Step 6.Create model to predict  for geting  the best prediction model type Linear Regression ,Logical , Random Forest,Driction Tree, SVM  if need add StandardScaler
Step 7 .After Geting the best prediction save the model and deploy for production

# %%
7.	A social media platform wants to detect fake user accounts based on user activity and profile data. 
    What type of ML problem is this, and what steps would you take to solve it?
ML
Superviesd
Classification
Step1. Create the dataset preprocess
Step2 . Import the pandas and upload the dataset
Step 3. Use get dummies for regression
Step 4. Split the input and output
Step 5. Import test train split and split
Step 6.Create model to predict  for geting  the best prediction model type Linear Regression ,Logical , Random Forest,Driction Tree, SVM  if need add StandardScaler
Step 7 .After Geting the best prediction save the model and deploy for production

# %%
8.	A marketing agency wants to segment customers into different groups based on their purchasing behavior. 
    What type of ML problem is this, and what steps would you take to solve it
ML
Clustering
Unsupervised Learning
Step1. Create the dataset and preprocess
Step2 . Import the pandas and upload the dataset
Step 3. Use get dummies for regression
Step 4. Split the input and output
Step 5. Import test train split and split
Step 6.Create model to predict  for geting  the best prediction model type Agglomerative Clustering and K-Means if need add StandardScaler
Step 7 .After Geting the best prediction save the model and deploy for production

# %%
9.	A geospatial research team wants to analyze satellite images to classify different land types (forest, water, urban).
    What type of ML problem is this, and what steps would you take to solve it?
ML
Superviesd
Classification
Step1. Create the dataset preprocess
Step2 . Import the pandas and upload the dataset
Step 3. Use get dummies for regression
Step 4. Split the input and output
Step 5. Import test train split and split
Step 6.Create model to predict  for geting  the best prediction model type Linear Regression ,Logical , Random Forest,Driction Tree, SVM  if need add StandardScaler
Step 7 .After Geting the best prediction save the model and deploy for production

# %%
10.	A streaming service wants to predict which users are likely to cancel their subscriptions. 
    What type of ML problem is this, and what steps would you take to solve it?
ML
Superviesd
Classification
Step1. Create the dataset preprocess
Step2 . Import the pandas and upload the dataset
Step 3. Use get dummies for regression
Step 4. Split the input and output
Step 5. Import test train split and split
Step 6.Create model to predict  for geting  the best prediction model type Linear Regression ,Logical , Random Forest,Driction Tree, SVM  if need add StandardScaler
Step 7 .After Geting the best prediction save the model and deploy for production
